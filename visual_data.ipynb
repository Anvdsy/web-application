# %% [markdown]
# <a href="https://colab.research.google.com/github/Anvdsy/web-application/blob/main/visual_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing the libraries

# %%
pip install klib

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Uploads_Annual-enterprise-survey_Annual-enterprise-survey-2021-financial-year-provisional_Download-data_annual-enterprise-survey-2021-financial-year-provisional-csv.csv")

# %% [markdown]
# Statistics information

# %%
df.describe()
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41715 entries, 0 to 41714
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         41715 non-null  int64
#  1   Industry_aggregation_NZSIOC  41715 non-null  object
#  2   Industry_code_NZSIOC         41715 non-null  object
#  3   Industry_name_NZSIOC         41715 non-null  object
#  4   Units                        41715 non-null  object
#  5   Variable_code                41715 non-null  object
#  6   Variable_name                41715 non-null  object
#  7   Variable_category            41715 non-null  object
#  8   Value                        41715 non-null  object
#  9   Industry_code_ANZSIC06       41715 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.2+ MB

# %%
df.isna()
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                 False
# 1      False                        False                 False
# 2      False                        False                 False
# 3      False                        False                 False
# 4      False                        False                 False
# ...      ...                          ...                   ...
# 41710  False                        False                 False
# 41711  False                        False                 False
# 41712  False                        False                 False
# 41713  False                        False                 False
# 41714  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False  False          False          False
# ...

# %%
df.isna().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %% [markdown]
# data visualization and finding important features

# %%
import klib

# %%
klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 9)

# %%
klib.corr_mat(df) # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_78704_row0_col0 {
#   color: None;
# }
# </style>
# <table id="T_78704" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78704_level0_col0" class="col_heading level0 col0" >Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78704_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_78704_row0_col0" class="data row0 col0" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
 klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/describe.py:383: RuntimeWarning: All-NaN axis encountered
#   vmax = np.round(np.nanmax(corr.where(~mask)) - 0.05, 2)
# /usr/local/lib/python3.10/dist-packages/klib/describe.py:384: RuntimeWarning: All-NaN axis encountered
#   vmin = np.round(np.nanmin(corr.where(~mask)) + 0.05, 2)
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df) # returns a distribution plot for every numeric feature
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <Axes: xlabel='Year', ylabel='Density'>

# %%
klib.missingval_plot(df) # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.

# %%
klib.corr_plot(df, split='pos') # displaying only positive correlations, other settings include threshold, cmap...
klib.corr_plot(df, split='neg') # displaying only negative correlations
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <Axes: title={'center': 'Feature-correlation (pearson)'}>
